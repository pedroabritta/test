# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    0.01  0.00  0.000000
# 0  0.01   1.0       0.0
# 1  0.01   2.0       0.0
# 2  0.01   3.0       0.0
# 3  0.01   4.0       0.0
# 4  0.01   5.0       0.0
